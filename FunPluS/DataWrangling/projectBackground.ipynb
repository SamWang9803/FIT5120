# %%
import os

# %%
import pandas as pd

# %%
for i in sorted(os.listdir()):
    if i.endswith('png') or i.endswith('jpg'): 
        print(i)
# Out:
# BackyardGarden.jpg
# BroomBrooom.jpg
# Bus.jpg
# ChristmasWinterBackground_jpg-01.jpg
# ClassRoom1.jpg
# CozyLivingRoom.jpg
# Forest1.jpg
# Graveyard1.jpg
# MysteriousExtraterristrial.jpg
# PublicGarden.jpg
# SpaceandSolarSystemBackground.jpg
# WinterIsComing.jpg
# summer_beach.jpg
# supermarket.jpg
# treasureShip.jpg

# %%
bg = {'backgroundPath':[i for i in sorted(os.listdir()) if i.endswith('png') or i.endswith('jpg')], 
'backgroundName':['Teatime <i class="fa-solid fa-mug-tea-saucer"></i>', 
                 'Hit the road <i class="fa-solid fa-car-on"></i>', 
                 'Broom Broom <i class="fa-solid fa-bus"></i>', 
                 'Winter Wonderland <i class="fa-solid fa-snowflakes"></i>',
                 'Books and pens and breaks <i class="fa-solid fa-school"></i>',
                 'Welcome home <i class="fa-solid fa-house-chimney-heart"></i>', 
                 'Into the Jungle <i class="fa-brands fa-pagelines"></i>',
                 'Spooky Spook <i class="fa-solid fa-ghost"></i>',
                 'Extraterrestrial <i class="fa-solid fa-planet-ringed"></i>',
                 'Sunset Park <i class="fa-solid fa-tree-deciduous"></i>',
                 'Into the Space <i class="fa-solid fa-rocket-launch"></i>',
                 'Winter is Coming <i class="fa-solid fa-leaf-maple"></i>',
                 'Summer Highlight <i class="fa-solid fa-sun"></i>',
                  'What to get next <i class="fa-solid fa-lollipop"></i>',
                 'Adventure Time <i class="fa-solid fa-gem"></i>'], 
'backgroundLicence':['license_certificate_RMZ6K2PQC9.txt',
                    'license_certificate_C2KHTAMRBL.txt',
                    'license_certificate_JF4VUPLQ9K.txt',
                    'license_certificate_64WAS85EKG.txt', 
                    'license_certificate_V48AWKPNTD.txt',
                    'license_certificate_Y8T3VMDUFR.txt',
                    'license_certificate_JWLAYXGKZF.txt',
                    'license_certificate_UGMP6SB9HN.txt',
                    'license_certificate_FG6NTR8QMC.txt',
                    'license_certificate_C23GHSNKJ4.txt',
                    'license_certificate_YBKCLUQ26Z.txt',
                    'license_certificate_X69FZA57VT.txt',
                    'license_certificate_V8QXET9FGN.txt',
                    'license_certificate_HGALJ5NQEX.txt',
                    'license_certificate_Q2ZM7YK4S3.txt']}

# %%
pd.DataFrame(bg)
# Out:
#                           backgroundPath  \
# 0                     BackyardGarden.jpg
# 1                        BroomBrooom.jpg
# 2                                Bus.jpg
# 3   ChristmasWinterBackground_jpg-01.jpg
# 4                         ClassRoom1.jpg
# 5                     CozyLivingRoom.jpg
# 6                            Forest1.jpg
# 7                         Graveyard1.jpg
# 8         MysteriousExtraterristrial.jpg
# 9                       PublicGarden.jpg
# 10     SpaceandSolarSystemBackground.jpg
# 11                    WinterIsComing.jpg
# 12                      summer_beach.jpg
# 13                       supermarket.jpg
# 14                      treasureShip.jpg
#
#                                        backgroundName  \
# 0   Teatime <i class="fa-solid fa-mug-tea-saucer">...
# 1     Hit the road <i class="fa-solid fa-car-on"></i>
# 2         Broom Broom <i class="fa-solid fa-bus"></i>
# 3   Winter Wonderland <i class="fa-solid fa-snowfl...
# ...

# %%
pd.DataFrame(bg).to_csv('projectBg.csv', index = False)
